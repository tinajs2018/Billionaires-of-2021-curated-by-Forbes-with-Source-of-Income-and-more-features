# %% [markdown]
# # About the data

# %% [markdown]
# Cutting all the dank vibes, let's get serious now! This Dataset contains "Name of the each Billionaires", "Country: They are based on!", "Source of their Income/ Company Name", "Their net worth that makes them richer than God" and "Their global position in terms of their net worth".

# %% [markdown]
# # Objective of the analysis

# %% [markdown]
# ## Lets predict in the upcoming years which countries will have the maximum number of billionaires in the world.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Billionaire.csv")
df.head()
# Out:
#                        Name NetWorth        Country         Source  Rank
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5

# %%
df.isnull().sum()
# Out:
# Name        0
# NetWorth    0
# Country     0
# Source      0
# Rank        0
# dtype: int64

# %% [markdown]
# data is clean

# %%
df['Country'].unique
# Out:
# <bound method Series.unique of 0       United States
# 1       United States
# 2              France
# 3       United States
# 4       United States
#             ...
# 2750            China
# 2751            China
# 2752            China
# 2753            China
# 2754            China
# Name: Country, Length: 2755, dtype: object>

# %%
counts= df['Country'].value_counts()
counts
# Out:
# United States           724
# China                   626
# India                   140
# Germany                 136
# Russia                  118
#                        ...
# Oman                      1
# Nepal                     1
# Liechtenstein             1
# Algeria                   1
# Eswatini (Swaziland)      1
# Name: Country, Length: 70, dtype: int64

# %% [markdown]
# It show the usa has the higest number of Billionaires

# %%
plt.figure(figsize=(16,6))
sns.countplot(df['Country'])

# %%
plt.figure(figsize=(10,23))
plt.barh(df['Country'],df['NetWorth'],color='green')
# Out:
# <BarContainer object of 2755 artists>

# %%
from sklearn.preprocessing import  LabelEncoder
le=LabelEncoder()

# %%
#  #creating a new data frame
# dfle=df
# dfle.Country= le.fit_transform(dfle.Country)
# dfle

# %%
df['Country']
# Out:
# 0       United States
# 1       United States
# 2              France
# 3       United States
# 4       United States
#             ...
# 2750            China
# 2751            China
# 2752            China
# 2753            China
# 2754            China
# Name: Country, Length: 2755, dtype: object

# %%
import numpy as np

# %%
from sklearn.preprocessing  import OneHotEncoder
ohe=OneHotEncoder( sparse=True)

# %%
one = ohe.fit_transform([data])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-480b58d10bfe> in <module>
# ----> 1 one = ohe.fit_transform([data])
#
# NameError: name 'data' is not defined

# %%
one
